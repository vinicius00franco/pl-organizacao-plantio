# %% [markdown]
# # Otimização do Mix de Culturas — Versão 5 (Organizada)
# Este notebook reorganiza o código: funções reutilizáveis, logging centralizado para `otimizacao_mix_culturas_v5_organized.txt`, e pontos claros para executar o dashboard separadamente.

# %%
# 0. Imports e configuração básica
import os
from datetime import datetime
import json
import pandas as pd
import numpy as np
import pulp
from pulp import LpProblem, LpVariable, LpMaximize, lpSum, value, LpStatus
from omegaconf import DictConfig, OmegaConf


NOTEBOOK_DIR = os.getcwd()
MASTER_LOG = os.path.join(NOTEBOOK_DIR, "otimizacao_mix_culturas_v5_organized.txt")

# Garante que o arquivo exista e seja gravável
try:
    with open(MASTER_LOG, "a", encoding="utf-8") as f:
        f.write(
            f"[{datetime.now().isoformat()}] --- INICIANDO NOVA SESSÃO DE LOG ---\n"
        )
except Exception as e:
    print(f"Falha ao criar/abrir arquivo de log principal: {e}")
# ---------------------------------------------

def print_and_log(message, logfile=MASTER_LOG):
    ts = datetime.now().isoformat(sep=" ", timespec="seconds")
    line = f"[{ts}] {message}"
    print(line)
    try:
        with open(logfile, "a", encoding="utf-8") as f:
            f.write(line + "\n")
    except Exception as e:
        print(f"Falha ao gravar log: {e}")

# %%
# 1. Função para gerar dados mock (reutilizável)
def generate_mock_data(n_dados=1500, seed=42, verbose=True):
    print_and_log(f'GERAR DADOS: n_dados={n_dados}, seed={seed}')
    np.random.seed(int(seed))
    df = pd.DataFrame({'id_talhao': range(1, n_dados + 1), 'cultura': np.random.choice(['Soja_Resistente','Soja_Produtiva','Milho_Safrinha'], n_dados)})

    culturas_params = {
        'Soja_Resistente': {'prod': (3.5,0.5),'custo':(1800,150),'agua':(450,50),'k':(80,10),'p':(70,8),'horas':(10,1.5)},
        'Soja_Produtiva': {'prod': (4.8,0.6),'custo':(2500,200),'agua':(600,60),'k':(100,12),'p':(90,10),'horas':(12,1.8)},
        'Milho_Safrinha': {'prod': (5.5,0.7),'custo':(2800,250),'agua':(700,70),'k':(120,15),'p':(100,12),'horas':(15,2.0)},
    }

    def gen(params, size):
        return {
            'produtividade_ton_ha': np.random.normal(loc=params['prod'][0], scale=params['prod'][1], size=size),
            'custo_ha': np.random.normal(loc=params['custo'][0], scale=params['custo'][1], size=size),
            'uso_agua_m3_ha': np.random.normal(loc=params['agua'][0], scale=params['agua'][1], size=size),
            'demanda_k_kg_ha': np.random.normal(loc=params['k'][0], scale=params['k'][1], size=size),
            'demanda_p_kg_ha': np.random.normal(loc=params['p'][0], scale=params['p'][1], size=size),
            'horas_maquina_ha': np.random.normal(loc=params['horas'][0], scale=params['horas'][1], size=size),
        }
    
    for cultura, params in culturas_params.items():
        mask = df['cultura'] == cultura
        data = gen(params, mask.sum())
        for k, vals in data.items():
            df.loc[mask, k] = vals
    
    if verbose:
        dist = df['cultura'].value_counts().to_dict()
        print_and_log('Distribuição por cultura: ' + json.dumps(dist, ensure_ascii=False))
        print_and_log('Dados mock gerados com sucesso. Amostra das primeiras linhas:')
        print_and_log(df.head(5).to_json(orient='records', force_ascii=False))
        print_and_log('Estatísticas resumidas:')
        print_and_log(df.describe().to_json(force_ascii=False))
    return df

# %%
# 2. Função que configura o modelo de otimização (recebe parâmetros agregados e recursos)
def setup_model_from_params(params_df, resources, percentual_minimo_por_cultura=0.15, percentual_maximo_soja_produtiva=0.60):
    # params_df: DataFrame com index = culturas e colunas medias por ha
    print_and_log('SETUP MODELO: iniciando criação do modelo')
    modelo = LpProblem(name='Otimizacao_Mix_Culturas_Risco', sense=LpMaximize)
    # Variáveis de decisão
    x_sr = LpVariable('Hectares_Soja_Resistente', lowBound=0, cat='Continuous')
    x_sp = LpVariable('Hectares_Soja_Produtiva', lowBound=0, cat='Continuous')
    x_ms = LpVariable('Hectares_Milho_Safrinha', lowBound=0, cat='Continuous')

    # Extrair parâmetros de forma robusta (usando .at para evitar KeyErrors)
    def val(cultura, col):
        try:
            return float(params_df.at[cultura, col])
        except Exception:
            return 0.0

    l_sr = val('Soja_Resistente','lucro_ha')
    l_sp = val('Soja_Produtiva','lucro_ha')
    l_ms = val('Milho_Safrinha','lucro_ha')
    c_sr = val('Soja_Resistente','custo_ha')
    c_sp = val('Soja_Produtiva','custo_ha')
    c_ms = val('Milho_Safrinha','custo_ha')
    a_sr = val('Soja_Resistente','uso_agua_m3_ha')
    a_sp = val('Soja_Produtiva','uso_agua_m3_ha')
    a_ms = val('Milho_Safrinha','uso_agua_m3_ha')
    k_sr = val('Soja_Resistente','demanda_k_kg_ha')
    k_sp = val('Soja_Produtiva','demanda_k_kg_ha')
    k_ms = val('Milho_Safrinha','demanda_k_kg_ha')
    p_sr = val('Soja_Resistente','demanda_p_kg_ha')
    p_sp = val('Soja_Produtiva','demanda_p_kg_ha')
    p_ms = val('Milho_Safrinha','demanda_p_kg_ha')
    h_sr = val('Soja_Resistente','horas_maquina_ha')
    h_sp = val('Soja_Produtiva','horas_maquina_ha')
    h_ms = val('Milho_Safrinha','horas_maquina_ha')
    prod_sr = val('Soja_Resistente','produtividade_ton_ha')
    prod_sp = val('Soja_Produtiva','produtividade_ton_ha')
    prod_ms = val('Milho_Safrinha','produtividade_ton_ha')

    # Gestão de risco: mínimos e máximos baseados em AREA_NAO_COMPACTADA_HA e parâmetros de política
    area_nc = float(resources.get('AREA_NAO_COMPACTADA_HA', 0))
    area_minima_ha = int(area_nc * float(percentual_minimo_por_cultura))
    area_maxima_sp = int(area_nc * float(percentual_maximo_soja_produtiva))
    print_and_log(f'REGRAS: min_por_cultura={percentual_minimo_por_cultura}, max_sp={percentual_maximo_soja_produtiva}, area_nc={area_nc}')

    modelo += (x_sr >= area_minima_ha, 'Minimo_Soja_Resistente')
    modelo += (x_sp >= area_minima_ha, 'Minimo_Soja_Produtiva')
    modelo += (x_ms >= area_minima_ha, 'Minimo_Milho_Safrinha')
    modelo += (x_sp <= area_maxima_sp, 'Risco_Maximo_Soja_Produtiva')

    # Objetivo
    modelo += lpSum([l_sr * x_sr, l_sp * x_sp, l_ms * x_ms]), 'Lucro_Total'

    # Restrições (área, orçamento, água, nutriente, horas, silo)
    modelo += (x_sr + x_sp + x_ms <= resources.get('AREA_TOTAL_DISPONIVEL_HA', 0), 'Restricao_Area_Total')
    modelo += (x_sr + x_sp + x_ms <= resources.get('AREA_NAO_COMPACTADA_HA', 0), 'Restricao_Area_Nao_Compactada')
    modelo += (c_sr * x_sr + c_sp * x_sp + c_ms * x_ms <= resources.get('ORCAMENTO_TOTAL_DISPONIVEL', 0), 'Restricao_Orcamento')
    modelo += (a_sr * x_sr + a_sp * x_sp + a_ms * x_ms <= resources.get('AGUA_TOTAL_DISPONIVEL_M3', 0), 'Restricao_Agua')
    modelo += (k_sr * x_sr + k_sp * x_sp + k_ms * x_ms <= resources.get('POTASSIO_DISPONIVEL_KG', 0), 'Restricao_Potassio')
    modelo += (p_sr * x_sr + p_sp * x_sp + p_ms * x_ms <= resources.get('FOSFORO_DISPONIVEL_KG', 0), 'Restricao_Fosforo')
    modelo += (h_sr * x_sr + h_sp * x_sp + h_ms * x_ms <= resources.get('HORAS_MAQUINA_DISPONIVEIS', 0), 'Restricao_Horas_Maquina')
    modelo += (prod_sr * x_sr + prod_sp * x_sp + prod_ms * x_ms <= resources.get('CAPACIDADE_SILO_TON', 0), 'Restricao_Armazenagem')

    print_and_log('SETUP MODELO: finalizado')
    return modelo, (x_sr, x_sp, x_ms)

# %%
# 3. Função que executa a otimização a partir de um DictConfig/Dict-like com 'params' e 'resources'
def run_optimization(cfg, logmaster=MASTER_LOG, verbose=True):
    # cfg: DictConfig ou dict com keys 'params' (contendo preco, n_dados, seed) e 'resources'
    params_in = cfg.get('params', {}) if isinstance(cfg, dict) else cfg.params
    resources = cfg.get('resources', {}) if isinstance(cfg, dict) else cfg.resources

    # Log de entrada de parâmetros
    print_and_log('RUN: parâmetros (params_in) => ' + json.dumps(OmegaConf.to_container(params_in, resolve=True) if isinstance(params_in, DictConfig) else params_in, ensure_ascii=False))
    print_and_log('RUN: recursos (resources) => ' + json.dumps(OmegaConf.to_container(resources, resolve=True) if isinstance(resources, DictConfig) else resources, ensure_ascii=False))

    df = generate_mock_data(int(params_in.get('n_dados',1500)), int(params_in.get('seed',42)), verbose=verbose)
    params = df.groupby('cultura').mean()
    # calcular lucro por ha por cultura usando preços do cfg
    preco_soja = float(params_in.get('preco_soja', 2200))
    preco_milho = float(params_in.get('preco_milho', 1300))
    perc_min = float(params_in.get('percentual_minimo_por_cultura', 0.15))
    perc_max_sp = float(params_in.get('percentual_maximo_soja_produtiva', 0.60))

    params['lucro_ha'] = 0.0
    params.at['Soja_Resistente','lucro_ha'] = params.at['Soja_Resistente','produtividade_ton_ha'] * preco_soja - params.at['Soja_Resistente','custo_ha']
    params.at['Soja_Produtiva','lucro_ha'] = params.at['Soja_Produtiva','produtividade_ton_ha'] * preco_soja - params.at['Soja_Produtiva','custo_ha']
    params.at['Milho_Safrinha','lucro_ha'] = params.at['Milho_Safrinha','produtividade_ton_ha'] * preco_milho - params.at['Milho_Safrinha','custo_ha']

    if verbose:
        print_and_log('PARAMS agregados por cultura:')
        print_and_log(params.to_json(force_ascii=False))

    modelo, variables = setup_model_from_params(params, resources, percentual_minimo_por_cultura=perc_min, percentual_maximo_soja_produtiva=perc_max_sp)
    print_and_log('Iniciando solução do modelo...', logfile=logmaster)
    try:
        solve_status = modelo.solve()
        status = LpStatus[modelo.status]
    except Exception as e:
        print_and_log(f'Falha ao executar solver: {e}', logfile=logmaster)
        raise

    print_and_log(f'Status do solver (raw): {solve_status}', logfile=logmaster)
    print_and_log(f'Status da otimização: {status}', logfile=logmaster)

    plantio = {v.name: v.varValue for v in variables} if status == 'Optimal' else None
    shadow = {name: getattr(con, 'pi', None) for name, con in modelo.constraints.items()}
    print_and_log('Plantio (resultado):', logfile=logmaster)
    print_and_log(str(plantio), logfile=logmaster)
    print_and_log('Preços sombra:', logfile=logmaster)
    print_and_log(str(shadow), logfile=logmaster)

    results = {'status': status, 'lucro': value(modelo.objective) if status == 'Optimal' else None, 'plantio': plantio, 'shadow_prices': shadow}
    return results

# %%
# 4. Execução segura de múltiplos cenários (usa arquivos em config/cenario)
def load_and_merge_scenarios(scenario_dir="config/cenario", base_name="base"):
    base_path = os.path.join(scenario_dir, f"{base_name}.yaml")
    print_and_log(f"Carregando cenários de {scenario_dir} (base={base_name})")

    # Garante que a configuração base seja um DictConfig vazio se o arquivo não existir
    base_cfg = OmegaConf.load(base_path)
    scenarios = {base_name: base_cfg}

    # --- CORREÇÃO 2: Lógica de Merge Robusta ---
    try:
        # Adicionado sorted() para uma ordem de execução previsível
        for filename in sorted(os.listdir(scenario_dir)):
            if filename.endswith(".yaml") and not filename.startswith(base_name):
                scenario_name = filename.replace(".yaml", "")
                scenario_path = os.path.join(scenario_dir, filename)

                scenario_cfg = OmegaConf.load(scenario_path)

                # CORREÇÃO: Cria uma CÓPIA da base e mescla o cenário nela.
                # Isso preserva a base original para os próximos cenários.
                merged_cfg = OmegaConf.merge(base_cfg.copy(), scenario_cfg)
                scenarios[scenario_name] = merged_cfg

    except FileNotFoundError:
        print_and_log(f"Diretório de cenários não encontrado: {scenario_dir}")
    except Exception as e:
        print_and_log(f"Ocorreu um erro ao carregar cenários: {e}")
    # --------------------------------------------------------
    print_and_log("Cenários carregados: " + ", ".join(scenarios.keys()))

    return scenarios  # Retornar os cenários carregados

# %%
# 5. Função utilitária para rodar todos os cenários do diretório e resumir resultados


def run_all_scenarios(
    scenario_dir="config/cenario",
    base_name="base",
    save_csv="resumo_cenarios.csv",
    verbose=True,
):
    scenarios = load_and_merge_scenarios(scenario_dir=scenario_dir, base_name=base_name)
    rows = []
    for name, cfg in scenarios.items():
        print_and_log(f"Executando cenário: {name}")
        try:
            res = run_optimization(cfg, verbose=verbose)
            rows.append(
                {
                    "cenario": name,
                    "status": res.get("status"),
                    "lucro": res.get("lucro"),
                    "plantio": json.dumps(res.get("plantio", {}), ensure_ascii=False),
                }
            )
        except Exception as e:
            print_and_log(f"Falha no cenário {name}: {e}")
            rows.append(
                {"cenario": name, "status": "Error", "lucro": None, "plantio": "{}"}
            )
    df = pd.DataFrame(rows)
    try:
        df.to_csv(save_csv, index=False)
        print_and_log(f"Resumo salvo em {save_csv}")
    except Exception as e:
        print_and_log(f"Falha ao salvar resumo {save_csv}: {e}")
    return df

# %%
# 6. Ponto de Execução Principal
# Garante que a pasta de configuração exista
if not os.path.exists("config/cenario"):
    print("ERRO: A pasta 'config/cenario' não foi encontrada.")
    print("Por favor, crie a pasta e os arquivos .yaml antes de executar.")
else:
    # Executa todos os cenários
    summary_df = run_all_scenarios(
        scenario_dir="config/cenario",
        base_name="base",
        save_csv="resumo_cenarios.csv",
        verbose=False,
    )

    # Exibe o DataFrame de resumo formatado
    if not summary_df.empty:
        print(
            summary_df.style.format(
                {
                    "lucro": "R$ {}",
                    "Hectares_Soja_Resistente": "{:,.2f} ha",
                    "Hectares_Soja_Produtiva": "{:,.2f} ha",
                    "Hectares_Milho_Safrinha": "{:,.2f} ha",
                }
            ).hide(axis="index")
        )
# Out:
# [2025-10-18 13:20:57] Carregando cenários de config/cenario (base=base)
# [2025-10-18 13:20:57] Cenários carregados: base, agressivo, conservador, crise_fertilizantes, preco_alto_soja, seca
# [2025-10-18 13:20:57] Executando cenário: base
# [2025-10-18 13:20:57] RUN: parâmetros (params_in) => {"n_dados": 1500, "seed": 42, "preco_soja": 2200, "preco_milho": 1300, "percentual_minimo_por_cultura": 0.15, "percentual_maximo_soja_produtiva": 0.6}
# [2025-10-18 13:20:57] RUN: recursos (resources) => {"AREA_TOTAL_DISPONIVEL_HA": 500, "ORCAMENTO_TOTAL_DISPONIVEL": 1100000, "AGUA_TOTAL_DISPONIVEL_M3": 250000, "POTASSIO_DISPONIVEL_KG": 45000, "FOSFORO_DISPONIVEL_KG": 42000, "AREA_NAO_COMPACTADA_HA": 400, "HORAS_MAQUINA_DISPONIVEIS": 6000, "CAPACIDADE_SILO_TON": 2500}
# [2025-10-18 13:20:57] GERAR DADOS: n_dados=1500, seed=42
# [2025-10-18 13:20:57] SETUP MODELO: iniciando criação do modelo
# [2025-10-18 13:20:57] REGRAS: min_por_cultura=0.15, max_sp=0.6, area_nc=400.0
# [2025-10-18 13:20:57] SETUP MODELO: finalizado
# [2025-10-18 13:20:57] Iniciando solução do modelo...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/vinicius/Downloads/estudo/po/PL/PL/venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/0c17b694e98e45ed870f92000bd1611b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/0c17b694e98e45ed870f92000bd1611b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 17 COLUMNS
# At line 49 RHS
# At line 62 BOUNDS
# At line 63 ENDATA
# Problem MODEL has 12 rows, 3 columns and 28 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-5) rows, 3 (0) columns and 21 (-7) elements
# 0  Obj 1100770.2 Dual inf 18346.17 (3)
# 1  Obj 2782302.1
# Optimal - objective value 2782302.1
# After Postsolve, objective 2782302.1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2782302.123 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# [2025-10-18 13:20:57] Status do solver (raw): 1
# [2025-10-18 13:20:57] Status da otimização: Optimal
# [2025-10-18 13:20:57] Plantio (resultado):
# [2025-10-18 13:20:57] {'Hectares_Soja_Resistente': 100.0, 'Hectares_Soja_Produtiva': 240.0, 'Hectares_Milho_Safrinha': 60.0}
# [2025-10-18 13:20:57] Preços sombra:
# [2025-10-18 13:20:57] {'Minimo_Soja_Resistente': -0.0, 'Minimo_Soja_Produtiva': -0.0, 'Minimo_Milho_Safrinha': -1510.4994, 'Risco_Maximo_Soja_Produtiva': 2112.9012, 'Restricao_Area_Total': -0.0, 'Restricao_Area_Nao_Compactada': 5914.5895, 'Restricao_Orcamento': -0.0, 'Restricao_Agua': -0.0, 'Restricao_Potassio': -0.0, 'Restricao_Fosforo': -0.0, 'Restricao_Horas_Maquina': -0.0, 'Restricao_Armazenagem': -0.0}
# [2025-10-18 13:20:57] Executando cenário: agressivo
# [2025-10-18 13:20:57] RUN: parâmetros (params_in) => {"n_dados": 1500, "seed": 42, "preco_soja": 2200, "preco_milho": 1300, "percentual_minimo_por_cultura": 0.15, "percentual_maximo_soja_produtiva": 0.8}
# [2025-10-18 13:20:57] RUN: recursos (resources) => {"AREA_TOTAL_DISPONIVEL_HA": 500, "ORCAMENTO_TOTAL_DISPONIVEL": 1100000, "AGUA_TOTAL_DISPONIVEL_M3": 250000, "POTASSIO_DISPONIVEL_KG": 45000, "FOSFORO_DISPONIVEL_KG": 42000, "AREA_NAO_COMPACTADA_HA": 400, "HORAS_MAQUINA_DISPONIVEIS": 6000, "CAPACIDADE_SILO_TON": 2500}
# [2025-10-18 13:20:57] GERAR DADOS: n_dados=1500, seed=42
# [2025-10-18 13:20:57] SETUP MODELO: iniciando criação do modelo
# [2025-10-18 13:20:57] REGRAS: min_por_cultura=0.15, max_sp=0.8, area_nc=400.0
# [2025-10-18 13:20:57] SETUP MODELO: finalizado
# [2025-10-18 13:20:57] Iniciando solução do modelo...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/vinicius/Downloads/estudo/po/PL/PL/venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/3ca47d2d63f040fc8a0a9e6d60cd53a0-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/3ca47d2d63f040fc8a0a9e6d60cd53a0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 17 COLUMNS
# At line 49 RHS
# At line 62 BOUNDS
# At line 63 ENDATA
# Problem MODEL has 12 rows, 3 columns and 28 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-5) rows, 3 (0) columns and 21 (-7) elements
# 0  Obj 1100770.2 Dual inf 18346.17 (3)
# 1  Obj 2866818.2
# Optimal - objective value 2866818.2
# After Postsolve, objective 2866818.2, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2866818.172 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# [2025-10-18 13:20:57] Status do solver (raw): 1
# [2025-10-18 13:20:57] Status da otimização: Optimal
# [2025-10-18 13:20:57] Plantio (resultado):
# [2025-10-18 13:20:57] {'Hectares_Soja_Resistente': 60.0, 'Hectares_Soja_Produtiva': 280.0, 'Hectares_Milho_Safrinha': 60.0}
# [2025-10-18 13:20:57] Preços sombra:
# [2025-10-18 13:20:57] {'Minimo_Soja_Resistente': -2112.9012, 'Minimo_Soja_Produtiva': -0.0, 'Minimo_Milho_Safrinha': -3623.4006, 'Risco_Maximo_Soja_Produtiva': -0.0, 'Restricao_Area_Total': -0.0, 'Restricao_Area_Nao_Compactada': 8027.4907, 'Restricao_Orcamento': -0.0, 'Restricao_Agua': -0.0, 'Restricao_Potassio': -0.0, 'Restricao_Fosforo': -0.0, 'Restricao_Horas_Maquina': -0.0, 'Restricao_Armazenagem': -0.0}
# [2025-10-18 13:20:57] Executando cenário: conservador
# [2025-10-18 13:20:57] RUN: parâmetros (params_in) => {"n_dados": 1500, "seed": 42, "preco_soja": 2200, "preco_milho": 1300, "percentual_minimo_por_cultura": 0.15, "percentual_maximo_soja_produtiva": 0.4}
# [2025-10-18 13:20:57] RUN: recursos (resources) => {"AREA_TOTAL_DISPONIVEL_HA": 500, "ORCAMENTO_TOTAL_DISPONIVEL": 1100000, "AGUA_TOTAL_DISPONIVEL_M3": 250000, "POTASSIO_DISPONIVEL_KG": 45000, "FOSFORO_DISPONIVEL_KG": 42000, "AREA_NAO_COMPACTADA_HA": 400, "HORAS_MAQUINA_DISPONIVEIS": 6000, "CAPACIDADE_SILO_TON": 2500}
# [2025-10-18 13:20:57] GERAR DADOS: n_dados=1500, seed=42
# [2025-10-18 13:20:57] SETUP MODELO: iniciando criação do modelo
# [2025-10-18 13:20:57] REGRAS: min_por_cultura=0.15, max_sp=0.4, area_nc=400.0
# [2025-10-18 13:20:57] SETUP MODELO: finalizado
# [2025-10-18 13:20:57] Iniciando solução do modelo...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/vinicius/Downloads/estudo/po/PL/PL/venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/98dc7753fd72427882f7cb4524a4392a-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/98dc7753fd72427882f7cb4524a4392a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 17 COLUMNS
# At line 49 RHS
# At line 62 BOUNDS
# At line 63 ENDATA
# Problem MODEL has 12 rows, 3 columns and 28 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-5) rows, 3 (0) columns and 21 (-7) elements
# 0  Obj 1100770.2 Dual inf 18346.17 (3)
# 1  Obj 2613270
# Optimal - objective value 2613270
# After Postsolve, objective 2613270, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2613270.026 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# [2025-10-18 13:20:57] Status do solver (raw): 1
# [2025-10-18 13:20:57] Status da otimização: Optimal
# [2025-10-18 13:20:57] Plantio (resultado):
# [2025-10-18 13:20:57] {'Hectares_Soja_Resistente': 180.0, 'Hectares_Soja_Produtiva': 160.0, 'Hectares_Milho_Safrinha': 60.0}
# [2025-10-18 13:20:57] Preços sombra:
# [2025-10-18 13:20:57] {'Minimo_Soja_Resistente': -0.0, 'Minimo_Soja_Produtiva': -0.0, 'Minimo_Milho_Safrinha': -1510.4994, 'Risco_Maximo_Soja_Produtiva': 2112.9012, 'Restricao_Area_Total': -0.0, 'Restricao_Area_Nao_Compactada': 5914.5895, 'Restricao_Orcamento': -0.0, 'Restricao_Agua': -0.0, 'Restricao_Potassio': -0.0, 'Restricao_Fosforo': -0.0, 'Restricao_Horas_Maquina': -0.0, 'Restricao_Armazenagem': -0.0}
# [2025-10-18 13:20:57] Executando cenário: crise_fertilizantes
# [2025-10-18 13:20:57] RUN: parâmetros (params_in) => {"n_dados": 1500, "seed": 42, "preco_soja": 2200, "preco_milho": 1300, "percentual_minimo_por_cultura": 0.15, "percentual_maximo_soja_produtiva": 0.6}
# [2025-10-18 13:20:57] RUN: recursos (resources) => {"AREA_TOTAL_DISPONIVEL_HA": 500, "ORCAMENTO_TOTAL_DISPONIVEL": 1100000, "AGUA_TOTAL_DISPONIVEL_M3": 250000, "POTASSIO_DISPONIVEL_KG": 31500, "FOSFORO_DISPONIVEL_KG": 29400, "AREA_NAO_COMPACTADA_HA": 400, "HORAS_MAQUINA_DISPONIVEIS": 6000, "CAPACIDADE_SILO_TON": 2500}
# [2025-10-18 13:20:57] GERAR DADOS: n_dados=1500, seed=42
# [2025-10-18 13:20:57] SETUP MODELO: iniciando criação do modelo
# [2025-10-18 13:20:57] REGRAS: min_por_cultura=0.15, max_sp=0.6, area_nc=400.0
# [2025-10-18 13:20:57] SETUP MODELO: finalizado
# [2025-10-18 13:20:57] Iniciando solução do modelo...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/vinicius/Downloads/estudo/po/PL/PL/venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/45f1ccc9fd1e4f5ba1876f6ead650552-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/45f1ccc9fd1e4f5ba1876f6ead650552-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 17 COLUMNS
# At line 49 RHS
# At line 62 BOUNDS
# At line 63 ENDATA
# Problem MODEL has 12 rows, 3 columns and 28 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-5) rows, 3 (0) columns and 21 (-7) elements
# 0  Obj 1100770.2 Dual inf 18346.17 (3)
# 1  Obj 2196438.6
# Optimal - objective value 2196438.6
# After Postsolve, objective 2196438.6, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2196438.573 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# [2025-10-18 13:20:57] Status do solver (raw): 1
# [2025-10-18 13:20:57] Status da otimização: Optimal
# [2025-10-18 13:20:57] Plantio (resultado):
# [2025-10-18 13:20:57] {'Hectares_Soja_Resistente': 60.0, 'Hectares_Soja_Produtiva': 196.48952, 'Hectares_Milho_Safrinha': 60.0}
# [2025-10-18 13:20:57] Preços sombra:
# [2025-10-18 13:20:57] {'Minimo_Soja_Resistente': -581.35885, 'Minimo_Soja_Produtiva': -0.0, 'Minimo_Milho_Safrinha': -5415.1132, 'Risco_Maximo_Soja_Produtiva': -0.0, 'Restricao_Area_Total': -0.0, 'Restricao_Area_Nao_Compactada': -0.0, 'Restricao_Orcamento': -0.0, 'Restricao_Agua': -0.0, 'Restricao_Potassio': 81.15006, 'Restricao_Fosforo': -0.0, 'Restricao_Horas_Maquina': -0.0, 'Restricao_Armazenagem': -0.0}
# [2025-10-18 13:20:57] Executando cenário: preco_alto_soja
# [2025-10-18 13:20:57] RUN: parâmetros (params_in) => {"n_dados": 1500, "seed": 42, "preco_soja": 2500, "preco_milho": 1300, "percentual_minimo_por_cultura": 0.15, "percentual_maximo_soja_produtiva": 0.6}
# [2025-10-18 13:20:57] RUN: recursos (resources) => {"AREA_TOTAL_DISPONIVEL_HA": 500, "ORCAMENTO_TOTAL_DISPONIVEL": 1100000, "AGUA_TOTAL_DISPONIVEL_M3": 250000, "POTASSIO_DISPONIVEL_KG": 45000, "FOSFORO_DISPONIVEL_KG": 42000, "AREA_NAO_COMPACTADA_HA": 400, "HORAS_MAQUINA_DISPONIVEIS": 6000, "CAPACIDADE_SILO_TON": 2500}
# [2025-10-18 13:20:57] GERAR DADOS: n_dados=1500, seed=42
# [2025-10-18 13:20:57] SETUP MODELO: iniciando criação do modelo
# [2025-10-18 13:20:57] REGRAS: min_por_cultura=0.15, max_sp=0.6, area_nc=400.0
# [2025-10-18 13:20:57] SETUP MODELO: finalizado
# [2025-10-18 13:20:57] Iniciando solução do modelo...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/vinicius/Downloads/estudo/po/PL/PL/venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/032435dac4f24fb2819044544089de84-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/032435dac4f24fb2819044544089de84-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 17 COLUMNS
# At line 49 RHS
# At line 62 BOUNDS
# At line 63 ENDATA
# Problem MODEL has 12 rows, 3 columns and 28 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-5) rows, 3 (0) columns and 21 (-7) elements
# 0  Obj 1250027.1 Dual inf 20833.784 (3)
# 1  Obj 3232085.2
# Optimal - objective value 3232085.2
# After Postsolve, objective 3232085.2, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3232085.231 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# [2025-10-18 13:20:57] Status do solver (raw): 1
# [2025-10-18 13:20:57] Status da otimização: Optimal
# [2025-10-18 13:20:57] Plantio (resultado):
# [2025-10-18 13:20:57] {'Hectares_Soja_Resistente': 100.0, 'Hectares_Soja_Produtiva': 240.0, 'Hectares_Milho_Safrinha': 60.0}
# [2025-10-18 13:20:57] Preços sombra:
# [2025-10-18 13:20:57] {'Minimo_Soja_Resistente': -0.0, 'Minimo_Soja_Produtiva': -0.0, 'Minimo_Milho_Safrinha': -2562.2441, 'Risco_Maximo_Soja_Produtiva': 2497.0259, 'Restricao_Area_Total': -0.0, 'Restricao_Area_Nao_Compactada': 6966.3342, 'Restricao_Orcamento': -0.0, 'Restricao_Agua': -0.0, 'Restricao_Potassio': -0.0, 'Restricao_Fosforo': -0.0, 'Restricao_Horas_Maquina': -0.0, 'Restricao_Armazenagem': -0.0}
# [2025-10-18 13:20:57] Executando cenário: seca
# [2025-10-18 13:20:57] RUN: parâmetros (params_in) => {"n_dados": 1500, "seed": 42, "preco_soja": 2200, "preco_milho": 1300, "percentual_minimo_por_cultura": 0.15, "percentual_maximo_soja_produtiva": 0.6}
# [2025-10-18 13:20:57] RUN: recursos (resources) => {"AREA_TOTAL_DISPONIVEL_HA": 500, "ORCAMENTO_TOTAL_DISPONIVEL": 1100000, "AGUA_TOTAL_DISPONIVEL_M3": 180000, "POTASSIO_DISPONIVEL_KG": 45000, "FOSFORO_DISPONIVEL_KG": 42000, "AREA_NAO_COMPACTADA_HA": 400, "HORAS_MAQUINA_DISPONIVEIS": 6000, "CAPACIDADE_SILO_TON": 2500}
# [2025-10-18 13:20:57] GERAR DADOS: n_dados=1500, seed=42
# [2025-10-18 13:20:57] SETUP MODELO: iniciando criação do modelo
# [2025-10-18 13:20:57] REGRAS: min_por_cultura=0.15, max_sp=0.6, area_nc=400.0
# [2025-10-18 13:20:57] SETUP MODELO: finalizado
# [2025-10-18 13:20:57] Iniciando solução do modelo...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/vinicius/Downloads/estudo/po/PL/PL/venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/17fe2262ff914a44a58124d7b54aed86-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/17fe2262ff914a44a58124d7b54aed86-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 17 COLUMNS
# At line 49 RHS
# At line 62 BOUNDS
# At line 63 ENDATA
# Problem MODEL has 12 rows, 3 columns and 28 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-5) rows, 3 (0) columns and 21 (-7) elements
# 0  Obj 1100770.2 Dual inf 18346.17 (3)
# 1  Obj 2116126.7
# Optimal - objective value 2116126.7
# After Postsolve, objective 2116126.7, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2116126.663 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# [2025-10-18 13:20:57] Status do solver (raw): 1
# [2025-10-18 13:20:57] Status da otimização: Optimal
# [2025-10-18 13:20:57] Plantio (resultado):
# [2025-10-18 13:20:57] {'Hectares_Soja_Resistente': 60.0, 'Hectares_Soja_Produtiva': 186.48491, 'Hectares_Milho_Safrinha': 60.0}
# [2025-10-18 13:20:57] Preços sombra:
# [2025-10-18 13:20:57] {'Minimo_Soja_Resistente': -110.04695, 'Minimo_Soja_Produtiva': -0.0, 'Minimo_Milho_Safrinha': -4989.6931, 'Risco_Maximo_Soja_Produtiva': -0.0, 'Restricao_Area_Total': -0.0, 'Restricao_Area_Nao_Compactada': -0.0, 'Restricao_Orcamento': -0.0, 'Restricao_Agua': 13.456173, 'Restricao_Potassio': -0.0, 'Restricao_Fosforo': -0.0, 'Restricao_Horas_Maquina': -0.0, 'Restricao_Armazenagem': -0.0}
# [2025-10-18 13:20:57] Resumo salvo em resumo_cenarios.csv
# <style type="text/css">
# </style>
# <table id="T_75d9e">
#   <thead>
#     <tr>
#       <th id="T_75d9e_level0_col0" class="col_heading level0 col0" >cenario</th>
#       <th id="T_75d9e_level0_col1" class="col_heading level0 col1" >status</th>
#       <th id="T_75d9e_level0_col2" class="col_heading level0 col2" >lucro</th>
#       <th id="T_75d9e_level0_col3" class="col_heading level0 col3" >plantio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_75d9e_row0_col0" class="data row0 col0" >base</td>
#       <td id="T_75d9e_row0_col1" class="data row0 col1" >Optimal</td>
#       <td id="T_75d9e_row0_col2" class="data row0 col2" >R$ 2782302.123084742</td>
#       <td id="T_75d9e_row0_col3" class="data row0 col3" >{"Hectares_Soja_Resistente": 100.0, "Hectares_Soja_Produtiva": 240.0, "Hectares_Milho_Safrinha": 60.0}</td>
#     </tr>
#     <tr>
#       <td id="T_75d9e_row1_col0" class="data row1 col0" >agressivo</td>
#       <td id="T_75d9e_row1_col1" class="data row1 col1" >Optimal</td>
#       <td id="T_75d9e_row1_col2" class="data row1 col2" >R$ 2866818.171745312</td>
#       <td id="T_75d9e_row1_col3" class="data row1 col3" >{"Hectares_Soja_Resistente": 60.0, "Hectares_Soja_Produtiva": 280.0, "Hectares_Milho_Safrinha": 60.0}</td>
#     </tr>
#     <tr>
#       <td id="T_75d9e_row2_col0" class="data row2 col0" >conservador</td>
#       <td id="T_75d9e_row2_col1" class="data row2 col1" >Optimal</td>
#       <td id="T_75d9e_row2_col2" class="data row2 col2" >R$ 2613270.0257636025</td>
#       <td id="T_75d9e_row2_col3" class="data row2 col3" >{"Hectares_Soja_Resistente": 180.0, "Hectares_Soja_Produtiva": 160.0, "Hectares_Milho_Safrinha": 60.0}</td>
#     </tr>
#     <tr>
#       <td id="T_75d9e_row3_col0" class="data row3 col0" >crise_fertilizantes</td>
#       <td id="T_75d9e_row3_col1" class="data row3 col1" >Optimal</td>
#       <td id="T_75d9e_row3_col2" class="data row3 col2" >R$ 2196438.5699599683</td>
#       <td id="T_75d9e_row3_col3" class="data row3 col3" >{"Hectares_Soja_Resistente": 60.0, "Hectares_Soja_Produtiva": 196.48952, "Hectares_Milho_Safrinha": 60.0}</td>
#     </tr>
#     <tr>
#       <td id="T_75d9e_row4_col0" class="data row4 col0" >preco_alto_soja</td>
#       <td id="T_75d9e_row4_col1" class="data row4 col1" >Optimal</td>
#       <td id="T_75d9e_row4_col2" class="data row4 col2" >R$ 3232085.2314695683</td>
#       <td id="T_75d9e_row4_col3" class="data row4 col3" >{"Hectares_Soja_Resistente": 100.0, "Hectares_Soja_Produtiva": 240.0, "Hectares_Milho_Safrinha": 60.0}</td>
#     </tr>
#     <tr>
#       <td id="T_75d9e_row5_col0" class="data row5 col0" >seca</td>
#       <td id="T_75d9e_row5_col1" class="data row5 col1" >Optimal</td>
#       <td id="T_75d9e_row5_col2" class="data row5 col2" >R$ 2116126.6561999507</td>
#       <td id="T_75d9e_row5_col3" class="data row5 col3" >{"Hectares_Soja_Resistente": 60.0, "Hectares_Soja_Produtiva": 186.48491, "Hectares_Milho_Safrinha": 60.0}</td>
#     </tr>
#   </tbody>
# </table>

# %%
# --- Smoke test de logging: grava e mostra as últimas linhas do log principal
print_and_log('SMOKE TEST: iniciando verificação do arquivo de log principal')
# Append a specific identifiable line
print_and_log('SMOKE TEST: linha de verificação')
# Agora lemos as últimas linhas do arquivo de log e mostramos
try:
    with open(MASTER_LOG, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    tail = lines[-20:] if len(lines) > 0 else []
    print('\n--- Últimas linhas do log ---')
    for ln in tail:
        print(ln.rstrip())
except Exception as e:
    print(f'Falha ao ler o arquivo de log: {e}')
# Out:
# [2025-10-18 13:20:57] SMOKE TEST: iniciando verificação do arquivo de log principal
# [2025-10-18 13:20:57] SMOKE TEST: linha de verificação
#
# --- Últimas linhas do log ---
# [2025-10-18 13:20:57] {'Hectares_Soja_Resistente': 100.0, 'Hectares_Soja_Produtiva': 240.0, 'Hectares_Milho_Safrinha': 60.0}
# [2025-10-18 13:20:57] Preços sombra:
# [2025-10-18 13:20:57] {'Minimo_Soja_Resistente': -0.0, 'Minimo_Soja_Produtiva': -0.0, 'Minimo_Milho_Safrinha': -2562.2441, 'Risco_Maximo_Soja_Produtiva': 2497.0259, 'Restricao_Area_Total': -0.0, 'Restricao_Area_Nao_Compactada': 6966.3342, 'Restricao_Orcamento': -0.0, 'Restricao_Agua': -0.0, 'Restricao_Potassio': -0.0, 'Restricao_Fosforo': -0.0, 'Restricao_Horas_Maquina': -0.0, 'Restricao_Armazenagem': -0.0}
# [2025-10-18 13:20:57] Executando cenário: seca
# [2025-10-18 13:20:57] RUN: parâmetros (params_in) => {"n_dados": 1500, "seed": 42, "preco_soja": 2200, "preco_milho": 1300, "percentual_minimo_por_cultura": 0.15, "percentual_maximo_soja_produtiva": 0.6}
# [2025-10-18 13:20:57] RUN: recursos (resources) => {"AREA_TOTAL_DISPONIVEL_HA": 500, "ORCAMENTO_TOTAL_DISPONIVEL": 1100000, "AGUA_TOTAL_DISPONIVEL_M3": 180000, "POTASSIO_DISPONIVEL_KG": 45000, "FOSFORO_DISPONIVEL_KG": 42000, "AREA_NAO_COMPACTADA_HA": 400, "HORAS_MAQUINA_DISPONIVEIS": 6000, "CAPACIDADE_SILO_TON": 2500}
# [2025-10-18 13:20:57] GERAR DADOS: n_dados=1500, seed=42
# [2025-10-18 13:20:57] SETUP MODELO: iniciando criação do modelo
# [2025-10-18 13:20:57] REGRAS: min_por_cultura=0.15, max_sp=0.6, area_nc=400.0
# [2025-10-18 13:20:57] SETUP MODELO: finalizado
# [2025-10-18 13:20:57] Iniciando solução do modelo...
# [2025-10-18 13:20:57] Status do solver (raw): 1
# [2025-10-18 13:20:57] Status da otimização: Optimal
# [2025-10-18 13:20:57] Plantio (resultado):
# [2025-10-18 13:20:57] {'Hectares_Soja_Resistente': 60.0, 'Hectares_Soja_Produtiva': 186.48491, 'Hectares_Milho_Safrinha': 60.0}
# [2025-10-18 13:20:57] Preços sombra:
# [2025-10-18 13:20:57] {'Minimo_Soja_Resistente': -110.04695, 'Minimo_Soja_Produtiva': -0.0, 'Minimo_Milho_Safrinha': -4989.6931, 'Risco_Maximo_Soja_Produtiva': -0.0, 'Restricao_Area_Total': -0.0, 'Restricao_Area_Nao_Compactada': -0.0, 'Restricao_Orcamento': -0.0, 'Restricao_Agua': 13.456173, 'Restricao_Potassio': -0.0, 'Restricao_Fosforo': -0.0, 'Restricao_Horas_Maquina': -0.0, 'Restricao_Armazenagem': -0.0}
# [2025-10-18 13:20:57] Resumo salvo em resumo_cenarios.csv
# [2025-10-18 13:20:57] SMOKE TEST: iniciando verificação do arquivo de log principal
# [2025-10-18 13:20:57] SMOKE TEST: linha de verificação

# %%
# 7. Integração climática por cenário: usa fetch_climate() e grava no MASTER_LOG
import sys, os
sys.path.append(os.path.abspath('.'))
from scripts.analise_clima import fetch_climate
print_and_log('INICIANDO INTEGRAÇÃO CLIMÁTICA PARA CENÁRIOS')
scenarios = load_and_merge_scenarios(scenario_dir='config/cenario', base_name='base')
rows = []
for name, scfg in scenarios.items():
    try:
        print_and_log(f'Processando cenário: {name}')
        # obter config como dict
        sc = OmegaConf.to_container(scfg, resolve=True) if not isinstance(scfg, dict) else scfg
        loc = sc.get('location', {}) or {}
        climate_cfg = {
            'lat': loc.get('lat', -12.5449),
            'lon': loc.get('lon', -55.7126),
            'years': int(loc.get('years', sc.get('params', {}).get('years', 2) or 2)),
            'media_historica': float(loc.get('media_historica', sc.get('params', {}).get('media_historica', 600.0) or 600.0)),
            'cache_days': int(loc.get('cache_days', 30)),
            'redis_url': loc.get('redis_url', None),
        }
        clim = fetch_climate(climate_cfg)
        fator = clim.get('fator')
        precipitacoes = clim.get('precipitacoes')
        print_and_log(f'Cenário={name} | fator_clima={fator} | precipitacoes={precipitacoes}')
        # roda otimização e anexa o fator climático aos resultados
        res = run_optimization(scfg, verbose=False)
        res['climate_factor'] = fator
        rows.append({'cenario': name, 'status': res.get('status'), 'lucro': res.get('lucro'), 'climate_factor': fator})
    except Exception as e:
        print_and_log(f'Erro ao processar cenário {name}: {e}')
        rows.append({'cenario': name, 'status': 'Error', 'lucro': None, 'climate_factor': None})

import pandas as pd
df = pd.DataFrame(rows)
out_path = 'resumo_cenarios_com_clima.csv'
try:
    df.to_csv(out_path, index=False)
    print_and_log(f'Resumo com clima salvo em {out_path}')
except Exception as e:
    print_and_log(f'Falha ao salvar resumo com clima: {e}')

print_and_log('Integração climática concluída para todos os cenários')

# %%
# 7. Integração climática por cenário: usa fetch_climate() e grava no MASTER_LOG
import sys, os, time
sys.path.append(os.path.abspath('.'))
from scripts.analise_clima import fetch_climate

print_and_log('INICIANDO INTEGRAÇÃO CLIMÁTICA PARA CENÁRIOS')
scenarios = load_and_merge_scenarios(scenario_dir='config/cenario', base_name='base')
rows = []
details = []


def fetch_with_retry(cfg, retries=2, delay=2):
    d = delay
    for i in range(retries+1):
        try:
            return fetch_climate(cfg)
        except Exception as e:
            print_and_log(f'fetch_climate falhou (tentativa {i}) com: {e}')
            if i < retries:
                time.sleep(d)
                d *= 2
    return None

for name, scfg in scenarios.items():
    try:
        print_and_log(f'Processando cenário: {name}')
        sc = OmegaConf.to_container(scfg, resolve=True) if not isinstance(scfg, dict) else scfg
        loc = sc.get('location', {}) or {}
        climate_cfg = {
            'lat': loc.get('lat', -12.5449),
            'lon': loc.get('lon', -55.7126),
            'years': int(loc.get('years', sc.get('params', {}).get('years', 2) or 2)),
            'media_historica': float(loc.get('media_historica', sc.get('params', {}).get('media_historica', 600.0) or 600.0)),
            'cache_days': int(loc.get('cache_days', 30)),
            'redis_url': loc.get('redis_url', None),
        }

        clim = fetch_with_retry(climate_cfg, retries=2, delay=2)
        if clim is None or clim.get('data') is None:
            print_and_log(f'ATENÇÃO: dados climáticos indisponíveis para cenário: {name}. Prosseguindo sem ajuste climático.')
            fator = None
            summary = None
        else:
            fator = clim.get('fator')
            summary = clim.get('summary')

        print_and_log(f'Cenário={name} | fator_clima={fator} | summary={summary}')

        # roda otimização e anexa o fator climático aos resultados
        res = run_optimization(scfg, verbose=False)
        res['climate_factor'] = fator
        rows.append({'cenario': name, 'status': res.get('status'), 'lucro': res.get('lucro'), 'climate_factor': fator})

        details.append({
            'cenario': name,
            'fator': fator,
            'precip_media_safra': summary.get('precip_media_safra') if summary else None,
            'precipitacao_mais_recente': summary.get('precipitacao_mais_recente') if summary else None,
            'precipitacao_relativa': summary.get('precipitacao_relativa') if summary else None,
            'fetch_method': summary.get('fetch_method') if summary else None,
            'used_years': summary.get('used_years') if summary else None,
        })

    except Exception as e:
        print_and_log(f'Erro ao processar cenário {name}: {e}')
        rows.append({'cenario': name, 'status': 'Error', 'lucro': None, 'climate_factor': None})
        details.append({'cenario': name, 'error': str(e)})

import pandas as pd
df = pd.DataFrame(rows)
out_path = 'resumo_cenarios_com_clima.csv'
out_path_detalhado = 'resumo_cenarios_com_clima_detalhado.csv'
try:
    df.to_csv(out_path, index=False)
    print_and_log(f'Resumo com clima salvo em {out_path}')
except Exception as e:
    print_and_log(f'Falha ao salvar resumo com clima: {e}')

try:
    pd.DataFrame(details).to_csv(out_path_detalhado, index=False)
    print_and_log(f'Resumo climático detalhado salvo em {out_path_detalhado}')
except Exception as e:
    print_and_log(f'Falha ao salvar resumo climático detalhado: {e}')

print_and_log('Integração climática concluída para todos os cenários')
